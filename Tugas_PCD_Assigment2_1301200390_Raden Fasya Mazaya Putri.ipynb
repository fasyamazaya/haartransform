# %% [markdown]
# ---
#
#
# **ASSIGNMENT 2**
#
# **Image Transform : Haar Method**

# %% [markdown]
# NIM : 1301200390
#
# Nama : Raden Fasya Mazaya Putri
#
#
# ---

# %% [markdown]
# Source (thanks to) [Maverick099](https://github.com/Maverick099/Haar-transform-using-python/tree/master)

# %%
# !git clone https://github.com/fasyamazaya/haartransform.git
# Out:
# Cloning into 'haartransform'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (4/4), 469.29 KiB | 6.90 MiB/s, done.

# %%
import matplotlib.pyplot as plt
import pywt.data
import cv2
import math as m
import numpy as np
from PIL import Image
import requests
from io import BytesIO

image = cv2.imread("/content/haartransform/sample2.jpg")
img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
img_array = np.float64(img)
img_array /= 255,

coeffs = pywt.dwt2(img_array, 'bior1.3')
LL, (LH, HL, HH) = coeffs
fig = plt.figure(figsize=(12, 4))
titles = ['Approximation', ' Horizontal detail',
          'Vertical detail', 'Diagonal detail']

for i, a in enumerate([LL, LH, HL, HH]):
    ax = fig.add_subplot(1, 4, i + 1)
    ax.imshow(a, interpolation="nearest", cmap=p.cm.gray)
    ax.set_title(titles[i], fontsize=10)
    ax.set_xticks([])
    ax.set_yticks([])

fig.tight_layout()
plt.show()
